# %%
import os
import sys

# add the 'src' directory as one where we can import modules
# os.pardir refers to parent directory. 
# src_dir = os.path.join(os.getcwd(), '../src') => works the same
src_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(src_dir)

# Load the "autoreload" extension
# %load_ext autoreload
# always reload modules marked with "%aimport"
# %autoreload 2

# %% [markdown]
# # Experiment 1
#
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : ../resources/emotion_words
# lsd_words : None
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emotion_words ../resources/emotion_words \
--model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : ../resources/emotion_words
# lsd_words : None
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 3.41 sec
# INFO:root:End features extraction of (463 docs) in 6.89 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    3.5s finished
# INFO:root:End in 3.5198 sec
# mean: 0.34274, std: 0.13795, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 2

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words ../resources/stopwords --emotion_words ../resources/emotion_words \
--model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.06 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : ../resources/stopwords
# emotion_words : ../resources/emotion_words
# lsd_words : None
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 23.01 sec
# INFO:root:End features extraction of (463 docs) in 23.77 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    2.7s finished
# INFO:root:End in 2.7116 sec
# mean: 0.28923, std: 0.12538, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 3

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --lsd_words ../resources/LSD2011_ALL.txt  \
--model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.06 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.52 sec
# INFO:root:End features extraction of (463 docs) in 38.90 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    4.5s finished
# INFO:root:End in 4.5402 sec
# mean: 0.22606, std: 0.11076, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 4

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --lsd_words ../resources/LSD2011_ALL.txt  \
--model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 3.49 sec
# INFO:root:End features extraction of (463 docs) in 43.05 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# features length -> 463
# ...

# %% [markdown]
# # Experiment 5

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words ../resources/stopwords --lsd_words ../resources/LSD2011_ALL.txt  \
--model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.06 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : ../resources/stopwords
# emotion_words : None
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 23.24 sec
# INFO:root:End features extraction of (463 docs) in 32.19 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# features length -> 463
# ...

# %% [markdown]
# # Experiment 6

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words ../resources/stopwords --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt  \
--model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : ../resources/stopwords
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 23.27 sec
# INFO:root:End features extraction of (463 docs) in 33.27 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# features length -> 463
# ...

# %% [markdown]
# # Experiment 7

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt  \
--model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.06 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.90 sec
# INFO:root:End features extraction of (463 docs) in 41.26 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    6.9s finished
# INFO:root:End in 6.8788 sec
# mean: 0.36939, std: 0.11636, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 8

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.41 sec
# INFO:root:End features extraction of (463 docs) in 1.41 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  1.6min finished
# INFO:root:End in 94.5832 sec
# mean: 0.38017, std: 0.10494, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# mean: 0.49805, std: 0.15000, params: {'clf__C': 1, 'clf__penalty': 'l2'}
# ...

# %% [markdown]
# # Experiment 9

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words ../resources/stopwords --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.06 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : ../resources/stopwords
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 23.88 sec
# INFO:root:End features extraction of (463 docs) in 23.88 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
# ...

# %% [markdown]
# # Experiment 10

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --word_feature True --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : True
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.53 sec
# INFO:root:End features extraction of (463 docs) in 2.71 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:   48.8s finished
# INFO:root:End in 48.9159 sec
# mean: 0.37196, std: 0.15784, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# mean: 0.45030, std: 0.16401, params: {'clf__C': 1, 'clf__penalty': 'l2'}
# ...

# %% [markdown]
# # Experiment 11

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --word_feature True --stop_words ../resources/stopwords --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : ../resources/stopwords
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : True
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 20.80 sec
# INFO:root:End features extraction of (463 docs) in 28.54 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:   17.5s finished
# INFO:root:End in 17.5753 sec
# mean: 0.40809, std: 0.14630, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 12

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --word_feature True --stop_words ../resources/stopwords --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.05 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : ../resources/stopwords
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : True
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 2.55 sec
# INFO:root:End features extraction of (463 docs) in 3.53 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:   47.0s finished
# INFO:root:End in 47.1112 sec
# mean: 0.44680, std: 0.14043, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 13

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emoticons ../resources/emoticons --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : None
# emoticons : ../resources/emoticons
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 2.14 sec
# INFO:root:End features extraction of (463 docs) in 3.19 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %% [markdown]
# # Experiment 14

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words hi --emotion_words ../resources/emotion_words --emoticons ../resources/emoticons --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : hi
# emotion_words : ../resources/emotion_words
# lsd_words : None
# emoticons : ../resources/emoticons
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 2.08 sec
# INFO:root:End features extraction of (463 docs) in 4.25 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    4.2s finished
# INFO:root:End in 4.2573 sec
# mean: 0.33507, std: 0.12698, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words hi --emotion_words ../resources/emotion_words --emoticons ../resources/emoticons --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : hi
# emotion_words : ../resources/emotion_words
# lsd_words : None
# emoticons : ../resources/emoticons
# word_feature : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 2.72 sec
# INFO:root:End features extraction of (463 docs) in 6.28 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    4.3s finished
# INFO:root:End in 4.3456 sec
# mean: 0.33507, std: 0.12698, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 15

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --ngram 12 --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.06 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : ('1', '2')
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.66 sec
# INFO:root:End features extraction of (463 docs) in 2.82 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# ...

# %% [markdown]
# # Experiment 16

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --ngram 14 --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.05 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : ('1', '4')
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.87 sec
# INFO:root:End features extraction of (463 docs) in 4.79 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %% [markdown]
# # Experiment 17

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --fiveWoneH 111111 --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 3.73 sec
# INFO:root:End features extraction of (463 docs) in 3.92 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    3.4s finished
# INFO:root:End in 3.4052 sec
# mean: 0.30796, std: 0.05147, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 18

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --fiveWoneH 111000 --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : ('1', '1', '1', '0', '0', '0')
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.93 sec
# INFO:root:End features extraction of (463 docs) in 1.99 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    2.4s finished
# INFO:root:End in 2.4054 sec
# mean: 0.27195, std: 0.11186, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %% [markdown]
# # Experiment 19

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --pos True --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : True
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.43 sec
# INFO:root:End features extraction of (463 docs) in 14.64 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 23
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    7.9s finished
# INFO:root:End in 8.1088 sec
# ...

# %% [markdown]
# # Experiment 20

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words True --ngram 14 --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : ('1', '4')
# 5w1h : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 1.87 sec
# INFO:root:End features extraction of (463 docs) in 4.55 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
# ...

# %% [markdown]
# # Experiment 21

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words True --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model lr --features_norm l2 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.06 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 1.84 sec
# INFO:root:End features extraction of (463 docs) in 59.02 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# ...

# %% [markdown]
# # Experiment 22

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words True --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model lr --features_norm l2 --num_topk_features 1000 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : lr
# features_norm : l2
# num_topk_features : 1000
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 1.92 sec
# INFO:root:End features extraction of (463 docs) in 41.09 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1000 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 2766
# ...

# %% [markdown]
# # Experiment 23

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model lr --features_norm l2 --num_topk_features 1000 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : lr
# features_norm : l2
# num_topk_features : 1000
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.82 sec
# INFO:root:End features extraction of (463 docs) in 63.65 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1000 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 3369
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# ...

# %% [markdown]
# # Experiment 24: SVC

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model svc --features_norm l2 --num_topk_features 1000 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = svc
# INFO:root:End loading training data (463 docs) in 0.05 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : None
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : svc
# features_norm : l2
# num_topk_features : 1000
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.84 sec
# INFO:root:End features extraction of (463 docs) in 63.95 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1000 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 3369
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# ...

# %% [markdown]
# # Experiment 25

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --stop_words True --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model svc --features_norm l2 --num_topk_features 1500 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = svc
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : svc
# features_norm : l2
# num_topk_features : 1500
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 1.78 sec
# INFO:root:End features extraction of (463 docs) in 42.09 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1500 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 2766
# ...

# %% [markdown]
# # Experiment 26

# %%
# Experiment 12 on SVC

# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --word_feature True --stop_words True --model svc --features_norm l2 --nfolds 10
# Out:
# data : ../data/train/emotion-large.2-label.tsv.gz
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = svc
# INFO:root:End loading training data (463 docs) in 0.04 sec
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : True
# ngrams : None
# fiveWoneH : None
# pos : False
# model : svc
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# removing stop words
# INFO:root:End pre-processing training data (463 docs) in 1.79 sec
# INFO:root:End features extraction of (463 docs) in 2.63 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 195
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# ...

# %% [markdown]
# # Experiment 27

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model lsvc --features_norm l2 --num_topk_features 1500 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lsvc
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : lsvc
# features_norm : l2
# num_topk_features : 1500
# nfolds : 10
# INFO:root:End pre-processing training data (463 docs) in 1.68 sec
# INFO:root:End features extraction of (463 docs) in 65.08 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1500 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 3369
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# ...

# %% [markdown]
# # Experiment 28

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model lr --num_topk_features 1000 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.04 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : lr
# features_norm : l2
# num_topk_features : 1000
# nfolds : 10
# INFO:root:End features extraction of (463 docs) in 103.48 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1000 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 2351
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (463 docs) in 0.04 sec
# INFO:root:End features extraction of (463 docs) in 0.05 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# features length -> 463
# feature length -> 3684
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --model lr --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.06 sec
# INFO:root:End features extraction of (463 docs) in 0.06 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# features length -> 463
# feature length -> 3684
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --model svc --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = svc
# INFO:root:End loading training data (463 docs) in 0.06 sec
# INFO:root:End features extraction of (463 docs) in 0.06 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : svc
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# features length -> 463
# feature length -> 3684
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model lr --num_topk_features 1000 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (463 docs) in 0.12 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : lr
# features_norm : l2
# num_topk_features : 1000
# nfolds : 10
# INFO:root:End features extraction of (463 docs) in 705.54 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1000 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 2791
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model lr --num_topk_features 1000 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = lr
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : count
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : lr
# features_norm : l2
# num_topk_features : 1000
# nfolds : 10
# INFO:root:End loading training data (463 docs) in 0.09 sec
# INFO:root:End features extraction of (463 docs) in 2.47 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1000 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# features length -> 463
# feature length -> 3533
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --feat count --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (463 docs) in 0.05 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((463, 14485) docs) in 1.86 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --feat count --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (463 docs) in 0.05 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((463, 14485) docs) in 1.81 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion-large.2-label.tsv.gz --feat tfidf --model nb --nfolds 2
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (463 docs) in 0.08 sec
# data : ../data/train/emotion-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : tfidf
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 2
# INFO:root:End features extraction of ((463, 14485) docs) in 1.82 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py:699: RuntimeWarning: divide by zero encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py:699: RuntimeWarning: divide by zero encountered in log
# ...

# %%
# %run ../src/models/gridsearch.py --data ../data/train/emotion.2-label.tsv.gz --feat count --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/emotion.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (297 docs) in 0.04 sec
# data : ../data/train/emotion.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : False
# stop_words : False
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((297, 13488) docs) in 0.23 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...
