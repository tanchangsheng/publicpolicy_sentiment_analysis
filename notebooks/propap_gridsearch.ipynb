# %%
import os
import sys

# add the 'src' directory as one where we can import modules
# os.pardir refers to parent directory. 
# src_dir = os.path.join(os.getcwd(), '../src') => works the same
src_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(src_dir)

# Load the "autoreload" extension
# %load_ext autoreload
# always reload modules marked with "%aimport"
# %autoreload 2

# %%
# Experiment 1
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --feat tfidf --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (421 docs) in 0.05 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : False
# stop_words : False
# feat : tfidf
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 16338) docs) in 0.35 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py:699: RuntimeWarning: divide by zero encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# ...

# %%
# experiment 2
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat tfidf --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (421 docs) in 0.06 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : tfidf
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 13888) docs) in 1.58 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py:699: RuntimeWarning: divide by zero encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# ...

# %%
# Experiment 3
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --stop_words True --feat tfidf --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = nb
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# feat : tfidf
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End loading training data (421 docs) in 0.04 sec
# INFO:root:End features extraction of ((421, 13755) docs) in 1.89 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py:699: RuntimeWarning: divide by zero encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# ...

# %%
# Experiment 4
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --feat count --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : False
# stop_words : False
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 16358) docs) in 0.31 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...

# %%
# Experiment 5
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat count --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 13888) docs) in 1.97 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...

# %%
# Experiment 6
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --stop_words True --feat count --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (421 docs) in 0.05 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 13755) docs) in 1.97 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...

# %%
# Experiment 7
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --feat count --model lr --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : False
# stop_words : False
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 16358) docs) in 0.32 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...

# %%
# Experiment 8
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat count --model lr --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 13888) docs) in 1.89 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...

# %%
# Experiment 9
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --stop_words True --feat count --model lr --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (421 docs) in 0.05 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# feat : count
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 13755) docs) in 2.40 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)
# ...

# %%
# Experiment 10
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --feat tfidf --model lr --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (421 docs) in 0.05 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : False
# stop_words : False
# feat : tfidf
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 16358) docs) in 0.32 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    6.0s finished
# INFO:root:End in 6.0279 sec
# mean: 0.74717, std: 0.01316, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %%
# Experiment 11
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat tfidf --model lr --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : tfidf
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 13888) docs) in 1.67 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    4.9s finished
# INFO:root:End in 4.9317 sec
# mean: 0.74625, std: 0.01716, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %%
# Experiment 12
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --stop_words True --feat tfidf --model lr --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : True
# feat : tfidf
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : None
# fiveWoneH : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of ((421, 13755) docs) in 1.97 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:    3.9s finished
# INFO:root:End in 3.8692 sec
# mean: 0.75664, std: 0.01117, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %%
# Experiment 13
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat dict --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model nb --num_topk_features 1000 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : dict
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : nb
# features_norm : l2
# num_topk_features : 1000
# nfolds : 10
# INFO:root:End features extraction of (421 docs) in 110.37 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1000 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# ...

# %%
# Experiment 14
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat dict --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 14 --fiveWoneH 111111 --pos True --model lr --num_topk_features 1000 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : dict
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '4')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : lr
# features_norm : l2
# num_topk_features : 1000
# nfolds : 10
# INFO:root:End features extraction of (421 docs) in 114.54 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Pipeline: Selecting 1000 best features by a chi-square test
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed: 11.2min finished
# INFO:root:End in 674.1617 sec
# ...

# %%
# Experiment 15
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat dict --ngram 13 --model lr --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = lr
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : dict
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : ('1', '3')
# fiveWoneH : None
# pos : False
# model : lr
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of (421 docs) in 37.77 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  6.7min finished
# INFO:root:End in 405.8048 sec
# mean: 0.75809, std: 0.00462, params: {'clf__C': 1, 'clf__penalty': 'l1'}
# ...

# %%
# Experiment 16
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat dict --ngram 13 --model nb --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = nb
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : dict
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : ('1', '3')
# fiveWoneH : None
# pos : False
# model : nb
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# INFO:root:End features extraction of (421 docs) in 40.55 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# /Users/changsheng/anaconda/lib/python3.6/site-packages/sklearn/naive_bayes.py:699: RuntimeWarning: divide by zero encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# ...

# %%
# Experiment 17
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat dict --ngram 13 --model svc --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = svc
# INFO:root:End loading training data (421 docs) in 0.06 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : dict
# emotion_words : None
# lsd_words : None
# emoticons : None
# word_feature : False
# ngrams : ('1', '3')
# fiveWoneH : None
# pos : False
# model : svc
# features_norm : l2
# num_topk_features : None
# nfolds : 10
# exracting dict features...
# ngrams : ('1', '3')
# INFO:root:End features extraction of (421 docs) in 53.50 sec
# INFO:root:Pipeline: Normalzing features with l2
# INFO:root:Performing Grid Search CV...
# feature length of first document -> 2173
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  7.8min finished
# INFO:root:End in 473.1909 sec
# ...

# %%
# Experiment 18
# %run ../src/models/gridsearch.py --data ../data/train/partisan-gov-large.2-label.tsv.gz --preprocess True --feat dict --emotion_words ../resources/emotion_words --lsd_words ../resources/LSD2011_ALL.txt --word_feature True --ngram 13 --fiveWoneH 111111 --pos True --model svc --num_topk_features 1500 --nfolds 10
# Out:
# INFO:root:Finding the parameters for: data =  ../data/train/partisan-gov-large.2-label.tsv.gz, clf = svc
# INFO:root:End loading training data (421 docs) in 0.04 sec
# data : ../data/train/partisan-gov-large.2-label.tsv.gz
# label_index : 0
# text_index : 1
# preprocess : True
# stop_words : False
# feat : dict
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# emoticons : None
# word_feature : True
# ngrams : ('1', '3')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# model : svc
# features_norm : l2
# num_topk_features : 1500
# nfolds : 10
# exracting dict features...
# emotion_words : ../resources/emotion_words
# lsd_words : ../resources/LSD2011_ALL.txt
# word_feature : True
# ngrams : ('1', '3')
# fiveWoneH : ('1', '1', '1', '1', '1', '1')
# pos : True
# INFO:root:End features extraction of (421 docs) in 97.21 sec
# INFO:root:Pipeline: Normalzing features with l2
# ...
